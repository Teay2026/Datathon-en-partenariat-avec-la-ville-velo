# %% [markdown]
# ## 1. Setup & Configuration

# %%
import sys
import os
import yaml

# Windows compatibility fix for PySpark
if sys.platform == "win32":
    import socketserver
    if not hasattr(socketserver, 'UnixStreamServer'):
        socketserver.UnixStreamServer = socketserver.TCPServer

from pyspark.sql import SparkSession

# Load configuration
with open("../../../../config/config.yml") as f:
    config = yaml.safe_load(f)

silver_dir = config["paths"]["silver_dir"]

print(f"✓ Silver directory: {silver_dir}")
# Out:
# ✓ Silver directory: data/silver

# %%
# Initialize Spark session (Windows configuration)
import tempfile

os.environ['PYSPARK_PYTHON'] = sys.executable
os.environ['PYSPARK_DRIVER_PYTHON'] = sys.executable

local_temp = tempfile.gettempdir()
os.environ['SPARK_LOCAL_DIRS'] = local_temp

spark = SparkSession.builder \
    .appName("CSV_to_Parquet") \
    .master("local[*]") \
    .config("spark.sql.adaptive.enabled", "false") \
    .config("spark.driver.host", "localhost") \
    .config("spark.driver.bindAddress", "localhost") \
    .config("spark.ui.enabled", "false") \
    .config("spark.executor.memory", "2g") \
    .config("spark.driver.memory", "2g") \
    .config("spark.local.dir", local_temp) \
    .config("spark.sql.shuffle.partitions", "4") \
    .getOrCreate()

spark.sparkContext.setLogLevel("WARN")

print(f"✓ Spark version: {spark.version}")
print(f"✓ Python: {sys.executable}")
# Out:
# ✓ Spark version: 3.5.3
# ✓ Python: c:\Users\medma\Documents\2025-2026\Big Data\datathon_velomenaj\venv\Scripts\python.exe

# %% [markdown]
# ## 2. Fonction de conversion

# %%
def convert_csv_to_parquet(csv_path, parquet_path, sep=";"):
    """
    Convert CSV file to Parquet format.
    
    Args:
        csv_path: Path to CSV file
        parquet_path: Output path for Parquet file
        sep: CSV separator (default: ";")
    """
    print(f"📖 Reading CSV: {csv_path}")
    df = spark.read.csv(csv_path, header=True, inferSchema=True, sep=sep)
    
    count = df.count()
    print(f"   ✓ Loaded {count:,} rows, {len(df.columns)} columns")
    
    # Show schema
    print("   Schema:")
    for field in df.schema.fields:
        print(f"      - {field.name}: {field.dataType.simpleString()}")
    
    print(f"\n💾 Writing Parquet: {parquet_path}")
    df.write.mode("overwrite").parquet(parquet_path)
    print(f"   ✓ Saved successfully")
    
    return df, count

print("✓ Function ready")
# Out:
# ✓ Function ready

# %% [markdown]
# ## 3. Conversion de silver_amenagements.csv

# %%
# Convert silver_amenagements.csv to Parquet
csv_path = "../../../../data/silver_amenagements.csv"
parquet_path = f"../{silver_dir}/silver_amenagements2"

df_amenagements, count = convert_csv_to_parquet(csv_path, parquet_path)
# Out:
# 📖 Reading CSV: ../../../../data/silver_amenagements.csv
#    ✓ Loaded 4,592 rows, 27 columns
#    Schema:
#       - nom: string
#       - commune1: string
#       - insee1: double
#       - commune2: string
#       - insee2: double
#       - reseau: string
#       - financementac: string
#       - typeamenagement: string
#       - typeamenagement2: string
#       - positionnement: string
#       - senscirculation: string
#       - environnement: string
#       - localisation: string
#       - typologiepiste: string
#       - revetementpiste: string
#       - domanialite: string
#       - reglementation: string
#       - zonecirculationapaisee: string
#       - anneelivraison: double
#       - longueur: string
#       - observation: string
#       - validite: string
#       - gid: int
#       - centroid_lat: double
#       - centroid_lon: double
#       - is_mock: boolean
#       - geocoded_at: timestamp
#
# 💾 Writing Parquet: ../data/silver/silver_amenagements2
#    ✓ Saved successfully

# %%
# Preview the data
print("\n📊 Preview:")
df_amenagements.show(5, truncate=50)
# Out:
# 📊 Preview:
# +------------------------------------+----------------------+-------+--------+------+------------------+------------------+--------------------+----------------+-----------------------------+---------------+-------------------+------------+------------------+--------------------------------------------------+-----------+-------------------------+----------------------+--------------+--------+----------------------------------+-----------------------------------+----+------------+------------+-------+-------------------------+
# |                                 nom|              commune1| insee1|commune2|insee2|            reseau|     financementac|     typeamenagement|typeamenagement2|               positionnement|senscirculation|      environnement|localisation|    typologiepiste|                                   revetementpiste|domanialite|           reglementation|zonecirculationapaisee|anneelivraison|longueur|                       observation|                           validite| gid|centroid_lat|centroid_lon|is_mock|              geocoded_at|
# +------------------------------------+----------------------+-------+--------+------+------------------+------------------+--------------------+----------------+-----------------------------+---------------+-------------------+------------+------------------+--------------------------------------------------+-----------+-------------------------+----------------------+--------------+--------+----------------------------------+-----------------------------------+----+------------+------------+-------+-------------------------+
# |                Chemin des Grenettes|             Quincieux|69163.0|    NULL|  NULL|Réseau de desserte|PROX/FIC DGEEP/VTP|Double sens cyclable|            NULL|Unilatérale unidirectionnelle|    Sens Unique|Voie de circulation|Sur chaussée|              NULL|                                              NULL|  Métropole|Contresens (sens réservé)|                  NULL|        2021.0| 1150,48|     Arrêté n°2020/204 le 08/12/20|                             Validé|6416|   45.918023|   4.7587563|  false|2025-12-19 16:40:48.94695|
# |           Rond-point des Monts d'Or|Lyon 9e Arrondissement|69389.0|    NULL|  NULL|Réseau de desserte|      OR DIEM/STEP|      Piste Cyclable|            NULL| Unilatérale bidirectionnelle|         Double|Voie de circulation|Sur trottoir|Piste sur trottoir|Matériaux liés (asphaltes, enrobés, bétons et n...|  Métropole|          Vélo facultatif|                  NULL|        2017.0|   46,21|Arrêté N°2017RP34014 du 01/12/2017|                             Validé|3751|   45.954282|    4.723643|   true|                     NULL|
# |                    Promenade Lénine|        Vaulx-en-Velin|69256.0|    NULL|  NULL| Réseau secondaire|      OR DIEM/STEP|          Voie verte|            NULL|                   Sans objet|         Double|               Parc|  Sans objet|              NULL|                                              NULL|  Métropole|               Voie verte|                  NULL|        2017.0|   54,60|                              NULL|                             Validé|3434|   45.772741|    4.966703|   true|                     NULL|
# |Piste parallèle au chemin des Vernes|      Décines-Charpieu|69275.0|    NULL|  NULL|Réseau de desserte|PROX/FIC DGEEP/VTP|      Piste Cyclable|            NULL| Unilatérale bidirectionnelle|         Double|               Parc|Sur chaussée|              NULL|                                              NULL|  Métropole|                     NULL|                  NULL|          NULL| 1131,86|                              NULL|En projet ou en cours de validation| 345|   45.749602|    4.721187|   true|                     NULL|
# |               8ème Rue Cité Berliet|          Saint-Priest|69290.0|    NULL|  NULL| Réseau secondaire|     PPI DGEEP VTP|      Piste Cyclable|            NULL|Unilatérale unidirectionnelle|    Sens Unique|Voie de circulation|Sur trottoir|Piste sur trottoir|Matériaux liés (asphaltes, enrobés, bétons et n...|  Métropole|          Vélo facultatif|               Zone 30|        2012.0|   37,18|                              NULL|                             Validé|5870|    45.73042|    4.795658|   true|                     NULL|
# +------------------------------------+----------------------+-------+--------+------+------------------+------------------+--------------------+----------------+-----------------------------+---------------+-------------------+------------+------------------+--------------------------------------------------+-----------+-------------------------+----------------------+--------------+--------+----------------------------------+-----------------------------------+----+------------+------------+-------+-------------------------+
# only showing top 5 rows

# %% [markdown]
# ## 4. Vérification du Parquet

# %%
# Re-read the Parquet to verify
df_verify = spark.read.parquet(parquet_path)

print(f"✓ Parquet file loaded: {df_verify.count()} rows")
print(f"✓ Columns: {df_verify.columns}")

# Compare row counts
assert df_verify.count() == count, "Row count mismatch!"
print("\n🎉 Verification passed!")
# Out:
# ✓ Parquet file loaded: 4592 rows
# ✓ Columns: ['nom', 'commune1', 'insee1', 'commune2', 'insee2', 'reseau', 'financementac', 'typeamenagement', 'typeamenagement2', 'positionnement', 'senscirculation', 'environnement', 'localisation', 'typologiepiste', 'revetementpiste', 'domanialite', 'reglementation', 'zonecirculationapaisee', 'anneelivraison', 'longueur', 'observation', 'validite', 'gid', 'centroid_lat', 'centroid_lon', 'is_mock', 'geocoded_at']
#
# 🎉 Verification passed!

# %% [markdown]
# ## 5. Conversion d'autres fichiers (optionnel)
#
# Décommentez et modifiez selon vos besoins.

# %%
# === Convertir d'autres fichiers CSV ===

# silver_sites
# convert_csv_to_parquet(
#     f"../{silver_dir}/silver_sites.csv",
#     f"../{silver_dir}/silver_sites"
# )

# silver_channels
# convert_csv_to_parquet(
#     f"../{silver_dir}/silver_channels.csv",
#     f"../{silver_dir}/silver_channels"
# )

# silver_measures
# convert_csv_to_parquet(
#     f"../{silver_dir}/silver_measures.csv",
#     f"../{silver_dir}/silver_measures"
# )

print("ℹ️  Décommentez les lignes ci-dessus pour convertir d'autres fichiers")

# %% [markdown]
# ## 6. Cleanup

# %%
# Stop Spark session
spark.stop()
print("✓ Spark session stopped")
